# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import pickle
from imblearn.over_sampling import ADASYN
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# Load the dataset
data_path = "/content/telecom_churn.csv"
df = pd.read_csv(data_path)

# %%
# Convert 'date_of_registration' to datetime and create 'tenure_days'
df['date_of_registration'] = pd.to_datetime(df['date_of_registration'])
df['tenure_days'] = (pd.Timestamp.today() - df['date_of_registration']).dt.days

# Fix negative values in numerical columns
df[['calls_made', 'sms_sent', 'data_used']] = df[['calls_made', 'sms_sent', 'data_used']].clip(lower=0)

# %%
# Display basic dataset info
print("Dataset Shape:", df.shape)
print("First 5 rows:\n", df.head())
# Out:
# Dataset Shape: (243553, 15)
# First 5 rows:
#     customer_id telecom_partner gender  age              state     city  \
# 0            1    Reliance Jio      F   25          Karnataka  Kolkata
# 1            2    Reliance Jio      F   55            Mizoram   Mumbai
# 2            3        Vodafone      F   57  Arunachal Pradesh    Delhi
# 3            4            BSNL      M   46         Tamil Nadu  Kolkata
# 4            5            BSNL      F   26            Tripura    Delhi
#
#    pincode date_of_registration  num_dependents  estimated_salary  calls_made  \
# 0   755597           2020-01-01               4            124962          44
# 1   125926           2020-01-01               2            130556          62
# 2   423976           2020-01-01               0            148828          49
# 3   522841           2020-01-01               1             38722          80
# 4   740247           2020-01-01               2             55098          78
#
#    sms_sent  data_used  churn  tenure_days
# 0        45          0      0         1904
# 1        39       5973      0         1904
# 2        24        193      1         1904
# 3        25       9377      1         1904
# 4        15       1393      0         1904

# %%
# Check for missing values
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  customer_id             0
# telecom_partner         0
# gender                  0
# age                     0
# state                   0
# city                    0
# pincode                 0
# date_of_registration    0
# num_dependents          0
# estimated_salary        0
# calls_made              0
# sms_sent                0
# data_used               0
# churn                   0
# tenure_days             0
# dtype: int64

# %%
# Encode categorical variables
categorical_cols = ['telecom_partner', 'gender', 'state', 'city']
label_encoders = {col: LabelEncoder().fit(df[col].astype(str)) for col in categorical_cols}
for col, le in label_encoders.items():
    df[col] = le.transform(df[col].astype(str))

# %%
# Handle missing values
df.fillna(df.median(), inplace=True)

# %%
# Log-transform skewed features
df[['calls_made', 'sms_sent', 'data_used', 'tenure_days']] = np.log1p(df[['calls_made', 'sms_sent', 'data_used', 'tenure_days']])

# %%
# Drop unnecessary columns
df.drop(columns=['customer_id', 'pincode', 'date_of_registration'], inplace=True, errors='ignore')

# %%
# Define features and target
X, y = df.drop(columns=['churn']), df['churn']

# %%
# Handle class imbalance using ADASYN
adasyn = ADASYN(sampling_strategy='minority', random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %%
# Feature scaling
scaler = StandardScaler()
X_train_scaled, X_test_scaled = scaler.fit_transform(X_train), scaler.transform(X_test)

# %%
# Define Neural Network Model
nn_model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    BatchNormalization(),
    Dropout(0.4),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
nn_model.compile(optimizer=keras.optimizers.AdamW(learning_rate=0.0005, weight_decay=1e-5), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
# Train the model
nn_model.fit(X_train_scaled, y_train, epochs=150, batch_size=128, validation_split=0.2, verbose=1, callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 31s 13ms/step - accuracy: 0.6208 - loss: 0.6783 - val_accuracy: 0.6745 - val_loss: 0.6109 - learning_rate: 5.0000e-04
# Epoch 2/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.6654 - loss: 0.6188 - val_accuracy: 0.6781 - val_loss: 0.6076 - learning_rate: 5.0000e-04
# Epoch 3/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.6713 - loss: 0.6124 - val_accuracy: 0.6810 - val_loss: 0.6032 - learning_rate: 5.0000e-04
# Epoch 4/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - accuracy: 0.6771 - loss: 0.6077 - val_accuracy: 0.6861 - val_loss: 0.5997 - learning_rate: 5.0000e-04
# Epoch 5/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.6800 - loss: 0.6038 - val_accuracy: 0.6878 - val_loss: 0.5971 - learning_rate: 5.0000e-04
# Epoch 6/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - accuracy: 0.6829 - loss: 0.6010 - val_accuracy: 0.6885 - val_loss: 0.5957 - learning_rate: 5.0000e-04
# Epoch 7/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.6819 - loss: 0.6023 - val_accuracy: 0.6893 - val_loss: 0.5957 - learning_rate: 5.0000e-04
# Epoch 8/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6832 - loss: 0.6005 - val_accuracy: 0.6891 - val_loss: 0.5952 - learning_rate: 5.0000e-04
# Epoch 9/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.6845 - loss: 0.5988 - val_accuracy: 0.6895 - val_loss: 0.5938 - learning_rate: 5.0000e-04
# Epoch 10/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.6860 - loss: 0.5983 - val_accuracy: 0.6913 - val_loss: 0.5933 - learning_rate: 5.0000e-04
# Epoch 11/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.6854 - loss: 0.5989 - val_accuracy: 0.6912 - val_loss: 0.5938 - learning_rate: 5.0000e-04
# Epoch 12/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - accuracy: 0.6874 - loss: 0.5964 - val_accuracy: 0.6910 - val_loss: 0.5931 - learning_rate: 5.0000e-04
# Epoch 13/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 51s 20ms/step - accuracy: 0.6867 - loss: 0.5970 - val_accuracy: 0.6900 - val_loss: 0.5928 - learning_rate: 5.0000e-04
# Epoch 14/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - accuracy: 0.6875 - loss: 0.5963 - val_accuracy: 0.6926 - val_loss: 0.5919 - learning_rate: 5.0000e-04
# Epoch 15/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - accuracy: 0.6869 - loss: 0.5967 - val_accuracy: 0.6930 - val_loss: 0.5918 - learning_rate: 5.0000e-04
# Epoch 16/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 35s 15ms/step - accuracy: 0.6908 - loss: 0.5931 - val_accuracy: 0.6924 - val_loss: 0.5911 - learning_rate: 5.0000e-04
# Epoch 17/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 37s 14ms/step - accuracy: 0.6891 - loss: 0.5955 - val_accuracy: 0.6926 - val_loss: 0.5917 - learning_rate: 5.0000e-04
# Epoch 18/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6900 - loss: 0.5942 - val_accuracy: 0.6932 - val_loss: 0.5908 - learning_rate: 5.0000e-04
# Epoch 19/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6886 - loss: 0.5947 - val_accuracy: 0.6930 - val_loss: 0.5904 - learning_rate: 5.0000e-04
# Epoch 20/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6916 - loss: 0.5926 - val_accuracy: 0.6943 - val_loss: 0.5899 - learning_rate: 5.0000e-04
# Epoch 21/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.6908 - loss: 0.5936 - val_accuracy: 0.6940 - val_loss: 0.5905 - learning_rate: 5.0000e-04
# Epoch 22/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.6907 - loss: 0.5923 - val_accuracy: 0.6929 - val_loss: 0.5895 - learning_rate: 5.0000e-04
# Epoch 23/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6910 - loss: 0.5922 - val_accuracy: 0.6947 - val_loss: 0.5888 - learning_rate: 5.0000e-04
# Epoch 24/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6906 - loss: 0.5928 - val_accuracy: 0.6949 - val_loss: 0.5887 - learning_rate: 5.0000e-04
# Epoch 25/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6905 - loss: 0.5918 - val_accuracy: 0.6960 - val_loss: 0.5879 - learning_rate: 5.0000e-04
# Epoch 26/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6908 - loss: 0.5919 - val_accuracy: 0.6956 - val_loss: 0.5882 - learning_rate: 5.0000e-04
# Epoch 27/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.6926 - loss: 0.5914 - val_accuracy: 0.6960 - val_loss: 0.5873 - learning_rate: 5.0000e-04
# Epoch 28/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6913 - loss: 0.5925 - val_accuracy: 0.6959 - val_loss: 0.5876 - learning_rate: 5.0000e-04
# Epoch 29/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6915 - loss: 0.5918 - val_accuracy: 0.6977 - val_loss: 0.5870 - learning_rate: 5.0000e-04
# Epoch 30/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6929 - loss: 0.5905 - val_accuracy: 0.6978 - val_loss: 0.5868 - learning_rate: 5.0000e-04
# Epoch 31/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6930 - loss: 0.5914 - val_accuracy: 0.6978 - val_loss: 0.5866 - learning_rate: 5.0000e-04
# Epoch 32/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - accuracy: 0.6932 - loss: 0.5906 - val_accuracy: 0.6977 - val_loss: 0.5864 - learning_rate: 5.0000e-04
# Epoch 33/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.6919 - loss: 0.5910 - val_accuracy: 0.6967 - val_loss: 0.5876 - learning_rate: 5.0000e-04
# Epoch 34/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6933 - loss: 0.5910 - val_accuracy: 0.6973 - val_loss: 0.5865 - learning_rate: 5.0000e-04
# Epoch 35/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.6941 - loss: 0.5902 - val_accuracy: 0.6984 - val_loss: 0.5856 - learning_rate: 5.0000e-04
# Epoch 36/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6945 - loss: 0.5892 - val_accuracy: 0.6992 - val_loss: 0.5859 - learning_rate: 5.0000e-04
# Epoch 37/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6952 - loss: 0.5881 - val_accuracy: 0.6988 - val_loss: 0.5853 - learning_rate: 5.0000e-04
# Epoch 38/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6939 - loss: 0.5889 - val_accuracy: 0.6980 - val_loss: 0.5853 - learning_rate: 5.0000e-04
# Epoch 39/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6954 - loss: 0.5888 - val_accuracy: 0.6983 - val_loss: 0.5857 - learning_rate: 5.0000e-04
# Epoch 40/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.6937 - loss: 0.5901 - val_accuracy: 0.6984 - val_loss: 0.5849 - learning_rate: 5.0000e-04
# Epoch 41/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6946 - loss: 0.5889 - val_accuracy: 0.6997 - val_loss: 0.5846 - learning_rate: 5.0000e-04
# Epoch 42/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.6948 - loss: 0.5886 - val_accuracy: 0.6984 - val_loss: 0.5844 - learning_rate: 5.0000e-04
# Epoch 43/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6970 - loss: 0.5868 - val_accuracy: 0.6990 - val_loss: 0.5850 - learning_rate: 5.0000e-04
# Epoch 44/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6972 - loss: 0.5866 - val_accuracy: 0.6992 - val_loss: 0.5852 - learning_rate: 5.0000e-04
# Epoch 45/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.6949 - loss: 0.5871 - val_accuracy: 0.6987 - val_loss: 0.5850 - learning_rate: 5.0000e-04
# Epoch 46/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6950 - loss: 0.5880 - val_accuracy: 0.6998 - val_loss: 0.5853 - learning_rate: 5.0000e-04
# Epoch 47/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.6976 - loss: 0.5867 - val_accuracy: 0.6981 - val_loss: 0.5847 - learning_rate: 5.0000e-04
# Epoch 48/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.6987 - loss: 0.5850 - val_accuracy: 0.7021 - val_loss: 0.5824 - learning_rate: 2.5000e-04
# Epoch 49/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.6979 - loss: 0.5851 - val_accuracy: 0.7011 - val_loss: 0.5825 - learning_rate: 2.5000e-04
# Epoch 50/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.6982 - loss: 0.5848 - val_accuracy: 0.7011 - val_loss: 0.5824 - learning_rate: 2.5000e-04
# Epoch 51/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.6996 - loss: 0.5843 - val_accuracy: 0.7019 - val_loss: 0.5821 - learning_rate: 2.5000e-04
# Epoch 52/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.6994 - loss: 0.5838 - val_accuracy: 0.7020 - val_loss: 0.5820 - learning_rate: 2.5000e-04
# Epoch 53/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6994 - loss: 0.5842 - val_accuracy: 0.7023 - val_loss: 0.5820 - learning_rate: 2.5000e-04
# Epoch 54/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.6991 - loss: 0.5838 - val_accuracy: 0.7010 - val_loss: 0.5822 - learning_rate: 2.5000e-04
# Epoch 55/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7013 - loss: 0.5826 - val_accuracy: 0.7004 - val_loss: 0.5822 - learning_rate: 2.5000e-04
# Epoch 56/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7013 - loss: 0.5813 - val_accuracy: 0.7005 - val_loss: 0.5819 - learning_rate: 2.5000e-04
# Epoch 57/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - accuracy: 0.6997 - loss: 0.5823 - val_accuracy: 0.7010 - val_loss: 0.5832 - learning_rate: 2.5000e-04
# Epoch 58/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.7005 - loss: 0.5832 - val_accuracy: 0.7019 - val_loss: 0.5811 - learning_rate: 1.2500e-04
# Epoch 59/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7020 - loss: 0.5801 - val_accuracy: 0.7028 - val_loss: 0.5809 - learning_rate: 1.2500e-04
# Epoch 60/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.7013 - loss: 0.5817 - val_accuracy: 0.7025 - val_loss: 0.5807 - learning_rate: 1.2500e-04
# Epoch 61/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - accuracy: 0.7019 - loss: 0.5810 - val_accuracy: 0.7017 - val_loss: 0.5810 - learning_rate: 1.2500e-04
# Epoch 62/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 30s 15ms/step - accuracy: 0.7034 - loss: 0.5807 - val_accuracy: 0.7019 - val_loss: 0.5807 - learning_rate: 1.2500e-04
# Epoch 63/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - accuracy: 0.7017 - loss: 0.5808 - val_accuracy: 0.7024 - val_loss: 0.5806 - learning_rate: 1.2500e-04
# Epoch 64/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.7008 - loss: 0.5815 - val_accuracy: 0.7021 - val_loss: 0.5806 - learning_rate: 1.2500e-04
# Epoch 65/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7015 - loss: 0.5804 - val_accuracy: 0.7021 - val_loss: 0.5807 - learning_rate: 1.2500e-04
# Epoch 66/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.7016 - loss: 0.5801 - val_accuracy: 0.7016 - val_loss: 0.5807 - learning_rate: 1.2500e-04
# Epoch 67/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7036 - loss: 0.5789 - val_accuracy: 0.7028 - val_loss: 0.5804 - learning_rate: 1.2500e-04
# Epoch 68/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7020 - loss: 0.5818 - val_accuracy: 0.7023 - val_loss: 0.5808 - learning_rate: 1.2500e-04
# Epoch 69/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.7020 - loss: 0.5807 - val_accuracy: 0.7021 - val_loss: 0.5809 - learning_rate: 1.2500e-04
# Epoch 70/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7035 - loss: 0.5788 - val_accuracy: 0.7021 - val_loss: 0.5807 - learning_rate: 1.2500e-04
# Epoch 71/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7024 - loss: 0.5801 - val_accuracy: 0.7026 - val_loss: 0.5803 - learning_rate: 1.2500e-04
# Epoch 72/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7028 - loss: 0.5794 - val_accuracy: 0.7025 - val_loss: 0.5804 - learning_rate: 1.2500e-04
# Epoch 73/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7038 - loss: 0.5794 - val_accuracy: 0.7023 - val_loss: 0.5802 - learning_rate: 6.2500e-05
# Epoch 74/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7032 - loss: 0.5792 - val_accuracy: 0.7027 - val_loss: 0.5800 - learning_rate: 6.2500e-05
# Epoch 75/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.7035 - loss: 0.5790 - val_accuracy: 0.7023 - val_loss: 0.5803 - learning_rate: 6.2500e-05
# Epoch 76/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7035 - loss: 0.5785 - val_accuracy: 0.7031 - val_loss: 0.5799 - learning_rate: 6.2500e-05
# Epoch 77/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7023 - loss: 0.5797 - val_accuracy: 0.7027 - val_loss: 0.5802 - learning_rate: 6.2500e-05
# Epoch 78/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7047 - loss: 0.5789 - val_accuracy: 0.7033 - val_loss: 0.5800 - learning_rate: 6.2500e-05
# Epoch 79/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.7043 - loss: 0.5790 - val_accuracy: 0.7026 - val_loss: 0.5800 - learning_rate: 6.2500e-05
# Epoch 80/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7043 - loss: 0.5778 - val_accuracy: 0.7026 - val_loss: 0.5802 - learning_rate: 6.2500e-05
# Epoch 81/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7042 - loss: 0.5780 - val_accuracy: 0.7031 - val_loss: 0.5800 - learning_rate: 6.2500e-05
# Epoch 82/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7035 - loss: 0.5802 - val_accuracy: 0.7030 - val_loss: 0.5800 - learning_rate: 3.1250e-05
# Epoch 83/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7031 - loss: 0.5785 - val_accuracy: 0.7029 - val_loss: 0.5799 - learning_rate: 3.1250e-05
# Epoch 84/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7041 - loss: 0.5784 - val_accuracy: 0.7032 - val_loss: 0.5799 - learning_rate: 3.1250e-05
# Epoch 85/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7050 - loss: 0.5778 - val_accuracy: 0.7030 - val_loss: 0.5798 - learning_rate: 3.1250e-05
# Epoch 86/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7045 - loss: 0.5788 - val_accuracy: 0.7030 - val_loss: 0.5799 - learning_rate: 3.1250e-05
# Epoch 87/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7049 - loss: 0.5781 - val_accuracy: 0.7025 - val_loss: 0.5799 - learning_rate: 3.1250e-05
# Epoch 88/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7040 - loss: 0.5784 - val_accuracy: 0.7030 - val_loss: 0.5797 - learning_rate: 3.1250e-05
# Epoch 89/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.7028 - loss: 0.5794 - val_accuracy: 0.7029 - val_loss: 0.5798 - learning_rate: 3.1250e-05
# Epoch 90/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7044 - loss: 0.5786 - val_accuracy: 0.7027 - val_loss: 0.5797 - learning_rate: 3.1250e-05
# Epoch 91/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7046 - loss: 0.5779 - val_accuracy: 0.7025 - val_loss: 0.5798 - learning_rate: 3.1250e-05
# Epoch 92/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7036 - loss: 0.5789 - val_accuracy: 0.7027 - val_loss: 0.5798 - learning_rate: 3.1250e-05
# Epoch 93/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7032 - loss: 0.5787 - val_accuracy: 0.7030 - val_loss: 0.5797 - learning_rate: 3.1250e-05
# Epoch 94/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7068 - loss: 0.5759 - val_accuracy: 0.7030 - val_loss: 0.5797 - learning_rate: 1.5625e-05
# Epoch 95/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.7036 - loss: 0.5787 - val_accuracy: 0.7030 - val_loss: 0.5797 - learning_rate: 1.5625e-05
# Epoch 96/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.7040 - loss: 0.5780 - val_accuracy: 0.7033 - val_loss: 0.5796 - learning_rate: 1.5625e-05
# Epoch 97/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7028 - loss: 0.5784 - val_accuracy: 0.7032 - val_loss: 0.5796 - learning_rate: 1.5625e-05
# Epoch 98/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7042 - loss: 0.5780 - val_accuracy: 0.7030 - val_loss: 0.5796 - learning_rate: 1.5625e-05
# Epoch 99/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7063 - loss: 0.5773 - val_accuracy: 0.7032 - val_loss: 0.5796 - learning_rate: 1.5625e-05
# Epoch 100/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - accuracy: 0.7052 - loss: 0.5767 - val_accuracy: 0.7033 - val_loss: 0.5795 - learning_rate: 1.5625e-05
# Epoch 101/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - accuracy: 0.7035 - loss: 0.5787 - val_accuracy: 0.7033 - val_loss: 0.5797 - learning_rate: 1.5625e-05
# Epoch 102/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - accuracy: 0.7050 - loss: 0.5779 - val_accuracy: 0.7033 - val_loss: 0.5796 - learning_rate: 7.8125e-06
# Epoch 103/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7050 - loss: 0.5775 - val_accuracy: 0.7030 - val_loss: 0.5796 - learning_rate: 7.8125e-06
# Epoch 104/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.7038 - loss: 0.5781 - val_accuracy: 0.7029 - val_loss: 0.5796 - learning_rate: 7.8125e-06
# Epoch 105/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7061 - loss: 0.5764 - val_accuracy: 0.7034 - val_loss: 0.5795 - learning_rate: 7.8125e-06
# Epoch 106/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.7051 - loss: 0.5775 - val_accuracy: 0.7032 - val_loss: 0.5796 - learning_rate: 7.8125e-06
# Epoch 107/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.7042 - loss: 0.5775 - val_accuracy: 0.7031 - val_loss: 0.5796 - learning_rate: 7.8125e-06
# Epoch 108/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7039 - loss: 0.5782 - val_accuracy: 0.7029 - val_loss: 0.5795 - learning_rate: 7.8125e-06
# Epoch 109/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7035 - loss: 0.5780 - val_accuracy: 0.7032 - val_loss: 0.5795 - learning_rate: 7.8125e-06
# Epoch 110/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7051 - loss: 0.5771 - val_accuracy: 0.7031 - val_loss: 0.5795 - learning_rate: 7.8125e-06
# Epoch 111/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7055 - loss: 0.5765 - val_accuracy: 0.7030 - val_loss: 0.5794 - learning_rate: 3.9063e-06
# Epoch 112/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.7034 - loss: 0.5789 - val_accuracy: 0.7033 - val_loss: 0.5795 - learning_rate: 3.9063e-06
# Epoch 113/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.7043 - loss: 0.5780 - val_accuracy: 0.7031 - val_loss: 0.5795 - learning_rate: 3.9063e-06
# Epoch 114/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.7038 - loss: 0.5788 - val_accuracy: 0.7033 - val_loss: 0.5795 - learning_rate: 3.9063e-06
# Epoch 115/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.7038 - loss: 0.5782 - val_accuracy: 0.7033 - val_loss: 0.5795 - learning_rate: 3.9063e-06
# Epoch 116/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - accuracy: 0.7047 - loss: 0.5778 - val_accuracy: 0.7032 - val_loss: 0.5795 - learning_rate: 1.9531e-06
# Epoch 117/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7050 - loss: 0.5783 - val_accuracy: 0.7032 - val_loss: 0.5795 - learning_rate: 1.9531e-06
# Epoch 118/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - accuracy: 0.7034 - loss: 0.5777 - val_accuracy: 0.7031 - val_loss: 0.5795 - learning_rate: 1.9531e-06
# Epoch 119/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7066 - loss: 0.5764 - val_accuracy: 0.7033 - val_loss: 0.5795 - learning_rate: 1.9531e-06
# Epoch 120/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7049 - loss: 0.5781 - val_accuracy: 0.7029 - val_loss: 0.5795 - learning_rate: 1.9531e-06
# Epoch 121/150
# 1953/1953 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.7046 - loss: 0.5775 - val_accuracy: 0.7030 - val_loss: 0.5795 - learning_rate: 1.0000e-06

# %%
# Make predictions
y_pred_probs_nn = nn_model.predict(X_test_scaled).flatten()
y_pred_nn = (y_pred_probs_nn >= 0.5).astype(int)
# Out:
# 2441/2441 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step

# %%
# Evaluate the model
accuracy_nn = accuracy_score(y_test, y_pred_nn)
balanced_acc_nn = balanced_accuracy_score(y_test, y_pred_nn)
roc_auc_nn = roc_auc_score(y_test, y_pred_probs_nn)

print(f"Neural Network - Accuracy: {accuracy_nn:.4f}\nBalanced Accuracy: {balanced_acc_nn:.4f}\nROC AUC Score: {roc_auc_nn:.4f}")
print("Classification Report:\n", classification_report(y_test, y_pred_nn))
# Out:
# Neural Network - Accuracy: 0.7019
# Balanced Accuracy: 0.7020
# ROC AUC Score: 0.7617
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.72      0.71     38945
#            1       0.71      0.68      0.70     39145
#
#     accuracy                           0.70     78090
#    macro avg       0.70      0.70      0.70     78090
# weighted avg       0.70      0.70      0.70     78090

# %%
# Train XGBoost model
xgb_model = XGBClassifier(n_estimators=200, learning_rate=0.05, max_depth=6, random_state=42)
xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# Train Random Forest model
rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
# Train Gradient Boosting model
gb_model = GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=6, random_state=42)
gb_model.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_depth=6, n_estimators=200,
#                            random_state=42)

# %%
# Define Stacking Classifier
estimators = [('rf', rf_model), ('xgb', xgb_model), ('gb', gb_model)]
stacking_model = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression(), cv=5)
stacking_model.fit(X_train_scaled, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('rf',
#                                 RandomForestClassifier(n_estimators=200,
#                                                        random_state=42)),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               grow_po...
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=6,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=200, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=42, ...)),
#                                ('gb',
#                                 GradientBoostingClassifier(learning_rate=0.05,
#                                                            max_depth=6,
#                                                            n_estimators=200,
#                                                            random_state=42))],
#                    final_estimator=LogisticRegression())

# %%
# Evaluate Stacking Model
y_pred_stack = stacking_model.predict(X_test_scaled)
accuracy_stack = accuracy_score(y_test, y_pred_stack)
balanced_acc_stack = balanced_accuracy_score(y_test, y_pred_stack)
roc_auc_stack = roc_auc_score(y_test, stacking_model.predict_proba(X_test_scaled)[:, 1])

print(f"Stacking Model - Accuracy: {accuracy_stack:.4f}\nBalanced Accuracy: {balanced_acc_stack:.4f}\nROC AUC Score: {roc_auc_stack:.4f}")
# Out:
# Stacking Model - Accuracy: 0.8030
# Balanced Accuracy: 0.8032
# ROC AUC Score: 0.8570

# %%
# Save models and scaler
nn_model.save("telecom_churn_nn_model_optimized.keras")
pickle.dump(scaler, open("scaler_optimized.pkl", "wb"))
pickle.dump(stacking_model, open("stacking_model.pkl", "wb"))

print("Optimized Models and Scaler saved successfully!")
# Out:
# Optimized Models and Scaler saved successfully!
